# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("resultado_filtro.csv")
df
## lee el archivo almacenado
# Out:
#       power  signal  delta  filtered
# 0       290     295      5         9
# 1       291     293      2         2
# 2       247     264     17        -2
# 3       284     259    -25       -10
# 4       244     248      4       -15
# 5       334     329     -5        -7
# 6       347     349      2        -4
# 7       328     307    -21        -8
# 8       196     207     11       -19
# 9       245     259     14       -29
# 10      252     186    -66       -44
# 11      207     151    -56       -39
# 12      210     155    -55       -33
# 13      224     170    -54       -27
# 14       58     140     82       -22
# 15      148     160     12       -15
# 16       95     150     55       -19
# 17      165     154    -11        -8
# 18      133     121    -12        -1
# 19      145     145      0        11
# 20      158     156     -2        17
# 21      119     105    -14        21
# 22       81      98     17        16
# 23       99      98     -1        19
# 24      125     168     43        16
# 25      125     160     35        27
# 26      179     199     20        30
# 27      204     208      4        29
# 28      236     275     39        27
# 29      256     255     -1        33
# ...     ...     ...    ...       ...
# 2756    231     222     -9         0
# 2757    221     214     -7        -8
# 2758    244     254     10        -6
# 2759    294     296      2         0
# 2760    269     274      5         6
# 2761    244     214    -30        16
# 2762    147     197     50        23
# 2763    177     201     24        27
# 2764     55     126     71        31
# 2765    145     153      8        33
# 2766    190     169    -21        21
# 2767     42      98     56        18
# 2768    166     122    -44        13
# 2769    234     175    -59         2
# 2770    125     119     -6        -3
# 2771    131     112    -19       -14
# 2772    113     110     -3       -27
# 2773    135     137      2       -25
# 2774    132     104    -28       -22
# 2775     64      66      2       -27
# 2776     66      70      4       -19
# 2777     71      88     17       -16
# 2778    169     143    -26       -14
# 2779    142     123    -19        -8
# 2780    211     189    -22        -8
# 2781    168     187     19        -8
# 2782    126     166     40       -12
# 2783    200     154    -46       -22
# 2784    131     147     16       -27
# 2785    328     247    -81       -25
#
# [2786 rows x 4 columns]

# %%
df.corr()
## mustra correlacion entre datos
# Out:
#              power    signal     delta  filtered
# power     1.000000  0.891262 -0.428034 -0.184568
# signal    0.891262  1.000000  0.028355  0.002024
# delta    -0.428034  0.028355  1.000000  0.410866
# filtered -0.184568  0.002024  0.410866  1.000000

# %%
plt.matshow(df.corr())
plt.colorbar()
## representa graficamente la correlacion entre datos

# %%
import seaborn as sns
sns.pairplot(df)
## grafica de correlacion

# %%
import statsmodels.api as sm

# %%
x_var = ['power','signal','delta']
x = df[x_var]
x = sm.add_constant(x)
y = df['filtered']

# %%
modelo = sm.OLS(y,x).fit()
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               filtered   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     282.8
# Date:                Sun, 25 Aug 2019   Prob (F-statistic):          1.57e-112
# Time:                        23:13:53   Log-Likelihood:                -12842.
# No. Observations:                2786   AIC:                         2.569e+04
# Df Residuals:                    2783   BIC:                         2.571e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.3062      1.320      6.293      0.000       5.718      10.894
# power         -0.1077      0.005    -21.266      0.000      -0.118      -0.098
# signal         0.1039      0.006     16.629      0.000       0.092       0.116
# delta          0.2116      0.009     23.086      0.000       0.194       0.230
# ==============================================================================
# Omnibus:                       21.494   Durbin-Watson:                   0.459
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.909
# Skew:                           0.214   Prob(JB):                     1.75e-05
# Kurtosis:                       2.930   Cond. No.                     1.55e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.76e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
fig, ax = plt.subplots(figsize = (10,8))
x= np.arange(len(y))
ax.plot(x,y,'k', label= 'data')
ax.plot(x, modelo.fittedvalues, 'b' , label= 'OLS')
